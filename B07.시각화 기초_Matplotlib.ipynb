# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from matplotlib import rc

font_loc = 'C:/Windows/Fonts/NanumGothic.ttf'
font_name = fm.FontProperties(fname=font_loc).get_name()

plt.rc('font', family=font_name)

print(font_name)
# Out:
# NanumGothic

# %%
import matplotlib.pylab as plt
st1 = [100, 110, 90, 105, 95, 102, 98]
st2 = [100, 90,80,120,80,160,40]

x = list(range(0,len(st1)))
x
# Out:
# [0, 1, 2, 3, 4, 5, 6]

# %%
plt.plot(x,st1)
plt.plot(x,st2)

# %%
plt.plot(x,st1,label='st1')
plt.plot(x,st2,label='st2')
plt.legend()

# %%
plt.plot(x,st1,label='st1')
plt.plot(x,st2,label='st2')
plt.legend(loc=2)

# %%
plt.title('Test Graph')
plt.plot(x,st1,label='st1')
plt.plot(x,st2,label='st2')
plt.legend(loc=2)

# %%
plt.title('Test Graph')
plt.bar(x,st1,label='st1')
plt.legend(loc=2)

# %%
plt.title('Test Graph')
plt.scatter(x,st1,label='st1')
plt.legend(loc=2)

# %%
plt.title('Test Graph')
plt.plot(x,st1,label='st1')
plt.bar(x,st1,label='st1')
plt.scatter(x,st1,label='st1')
plt.xlabel('x축')
plt.ylabel('y축')
plt.legend(loc=2)

# %%
plt.title('기본 그래프')
plt.plot(x,st1,label='st1')
plt.bar(x,st1,label='st1')
plt.scatter(x,st1,label='st1')
plt.xlabel('x축')
plt.ylabel('y축')
plt.legend(loc=2)

# %%
plt.title('기본 그래프')
plt.bar(x,st1,color = 'green',label='막대')
plt.plot(x,st1)
plt.scatter(x,st1,color='red',label='점')
plt.xlabel('x축')
plt.ylabel('y축')
plt.legend(loc=10)
plt.show()
# Out:
# C:\Users\wjswl\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51216 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\wjswl\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 47561 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\wjswl\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 45824 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\wjswl\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 51216 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\wjswl\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 47561 missing from current font.
#   font.set_text(s, 0, flags=flags)
# ...

# %%
plt.title('기본 그래프')
plt.bar(x,st1,color = 'green',label='막대')
plt.plot(x,st1)
plt.scatter(x,st1,color='red',label='점')
plt.xlabel('x축')
plt.ylabel('y축')
plt.legend(loc=10)
plt.grid(True)
plt.show()

# %%
import numpy as np
x_index=np.arange(len(st1))

plt.bar(x_index-0.3,st1,width=0.3,color='green',label='초록막대')
plt.bar(x_index,st2,width=0.3,color='blue',label='파란막대')

plt.xlabel('X축')
plt.ylabel('Y축')

plt.legend(loc=2)
plt.grid(True)
plt.show()
# Out:
# C:\Users\wjswl\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 52488 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\wjswl\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 47197 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\wjswl\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 54028 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\wjswl\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 46976 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\wjswl\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 52488 missing from current font.
#   font.set_text(s, 0, flags=flags)
# ...

# %%
import matplotlib as mpl
mpl.matplotlib_fname()
# Out:
# 'C:\\Users\\wjswl\\anaconda3\\lib\\site-packages\\matplotlib\\mpl-data\\matplotlibrc'

# %%
import matplotlib.pyplot as plt

ratio=[34,20,15,31]
label = ['apple','grape','banana','melon']

plt.pie(x=ratio, labels=label)
plt.show()

# %%
plabel=x
pvalue=st1

plt.pie(x=st1,labels=x,autopct='%.1f%%')
plt.show()

# %%
explode=[0.1,0.10,0.1,0.10,0.1,0.1,0.1]
plt.pie(x=st1,labels=x,autopct='%.1f%%',explode=explode)
plt.show()

# %%
import seaborn as sns
import pandas as pd
csData = pd.read_csv('C:/Users/wjswl/study_spark/data/customerdata.csv')
csData.head(2)
# Out:
#    CUSTID    AVGPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE
# 0  A13566  4273.90000    3            6    1.679181  Big-Screen-lover
# 1  A14219  3642.44195    2            4    2.682023      Sleeping-dog

# %%
sns.countplot(data=csData,x='EMI',hue='CUSTTYPE')
# Out:
# <AxesSubplot:xlabel='EMI', ylabel='count'>

# %%
figure = plt.figure(figsize=(18,6))

ax1 = plt.subplot(1,2,1)
sns.distplot(csData.AVGPRICE,kde=False,ax=ax1)
ax2= plt.subplot(1,2,2)
sns.distplot(csData.AVGPRICE,hist=False,ax=ax2)
# Out:
# C:\Users\wjswl\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\wjswl\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='AVGPRICE', ylabel='Density'>

# %%
sns.barplot(x='EMI',y='AVGPRICE',data=csData)
# Out:
# <AxesSubplot:xlabel='EMI', ylabel='AVGPRICE'>

# %%
sns.boxplot(data=csData, x='EMI',y='AVGPRICE')
# Out:
# <AxesSubplot:xlabel='EMI', ylabel='AVGPRICE'>
